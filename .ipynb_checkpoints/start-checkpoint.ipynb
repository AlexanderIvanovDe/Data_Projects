# %%
import pandas as pd
print("Всё РАБОТАЕТ!")

# %%
import numpy as np 
print("Библиотека NumPy тоже готова")

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect('Chinook_Sqlite.sqlite')

query = """
SELECT trackid,name,composer 
FROM track 
limit 10
"""

df = pd.read_sql_query(query,conn)

conn.close

df

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# 1. Загрузка данных
conn = sqlite3.connect('Chinook_Sqlite.sqlite')
query = """
SELECT 
    strftime('%Y-%m', InvoiceDate) AS Month,
    ROUND(AVG(Total), 2) AS AverageTotal
FROM Invoice
GROUP BY Month
ORDER BY Month DESC
LIMIT 24;
"""
df_sales = pd.read_sql_query(query, conn)
conn.close()

df_sales = df_sales.sort_values('Month').reset_index(drop=True)

# 2. Математическое сглаживание (Кубический сплайн)
x_indexes = np.arange(len(df_sales))
x_smooth = np.linspace(x_indexes.min(), x_indexes.max(), 300)

spline = make_interp_spline(x_indexes, df_sales['AverageTotal'], k=3)
y_smooth = spline(x_smooth)

# 3. Отрисовка
plt.figure(figsize=(13, 6))

for i in range(len(x_smooth) - 1):
    val = y_smooth[i]
    if val > 6.0:
        c = '#2ecc71'  # Зеленый
    elif val < 5.0:
        c = '#2c3e50'  # Черный
    else:
        c = '#95a5a6'  # Серый
    
    plt.plot(x_smooth[i:i+2], y_smooth[i:i+2], color=c, linewidth=3.5, zorder=2)

colors = ['#2ecc71' if v > 6.0 else '#2c3e50' if v < 5.0 else '#95a5a6' for v in df_sales['AverageTotal']]
plt.scatter(x_indexes, df_sales['AverageTotal'], color=colors, s=50, zorder=3)

# 4. Подписи над точками (каждый 3-й месяц)
for i in range(0, len(df_sales), 3):
    val = df_sales['AverageTotal'][i]
    plt.annotate(
        f"${val}", 
        (x_indexes[i], val), 
        textcoords="offset points", 
        xytext=(0, 10), 
        ha='center', 
        fontsize=9, 
        fontweight='bold'
    )

# 5. Настройка осей
plt.xticks(x_indexes[::3], df_sales['Month'][::3], rotation=45, fontsize=10)

plt.title('Динамика среднего чека (Сглаженный сплит с порогами)', fontsize=13, fontweight='bold', pad=15)
plt.xlabel('Месяц (каждый 3-й)', fontsize=11)
plt.ylabel('Средний чек ($)', fontsize=11)
plt.grid(True, linestyle=':', alpha=0.5, zorder=1)
plt.tight_layout()

plt.show()
